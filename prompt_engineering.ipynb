# %%
import os
import openai

client = openai.OpenAI(
    base_url="https://api.groq.com/openai/v1",
    api_key=os.getenv("GROQ_API_KEY")  # Set your API key in environment variables
)

response = client.chat.completions.create(
    model="llama-3.1-8b-instant",
    messages=[{"role": "user", "content": "Who is harry potter? "}],
    temperature=0,
)

print(response.choices[0].message.content)
# Out:
# Harry Potter is the main protagonist in a series of fantasy novels written by J.K. Rowling. He is a young wizard who attends Hogwarts School of Witchcraft and Wizardry. The series follows Harry's adventures and struggles as he navigates the magical world, makes friends, and battles against the dark wizard, Lord Voldemort.
#
# Harry Potter is an orphan who lives with his cruel and neglectful Muggle (non-magical) relatives, the Dursleys. On his eleventh birthday, he discovers that he is a wizard and begins to learn about his true identity and the magical world.
#
# Throughout the series, Harry forms close friendships with Ron Weasley and Hermione Granger, and together they become entangled in a battle against Voldemort, who murdered Harry's parents and seeks to return to power. Along the way, Harry must confront his own destiny, learn about his parents' past, and master his magical abilities.
#
# The Harry Potter series has become a cultural phenomenon, inspiring movies, merchandise, and a devoted fan base. The books have been translated into over 80 languages and have sold more than 500 million copies worldwide.
#
# Some of Harry's key characteristics include:
#
# - Bravery: Harry is willing to risk his life to protect his friends and the wizarding world.
# - Loyalty: He is fiercely loyal to his friends and will do whatever it takes to support them.
# - Empathy: Harry is able to understand and connect with others, even those who are different from him.
# - Determination: He is driven to uncover the truth and defeat Voldemort, even in the face of adversity.
#
# Overall, Harry Potter is a beloved and iconic character who has captured the hearts of readers and audiences around the world.
